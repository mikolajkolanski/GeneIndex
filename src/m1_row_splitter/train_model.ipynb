# %%
import os
import subprocess

# Find the root of the current git repository (usually your uv project root)
root = 'f:\\Projects\\GeneIndex'
os.chdir(root)

print(f"Current working directory: {os.getcwd()}")
# Out:
# Current working directory: f:\Projects\GeneIndex

# %%
import torch
import torch.nn as nn
from PIL import Image
import pandas as pd
import numpy as np
import json
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import v2
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.utils.data import random_split
from torchvision import tv_tensors
from torchvision.models.detection.rpn import AnchorGenerator
from torchvision.models.detection.backbone_utils import mobilenet_backbone
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from torchvision.models.detection.transform import GeneralizedRCNNTransform

from pathlib import Path
from sklearn.model_selection import GroupShuffleSplit

from torch.utils.tensorboard import SummaryWriter
import io

# %%
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
DEVICE
# Out:
# 'cuda'

# %%
def read_labels(images_path:Path, labels_file_path:Path|None=None):
    if labels_file_path is None:
        labels_file_path = images_path / '0_labels.json'

    labs_json = json.load(labels_file_path.open())

    labs = []
    imgs = []   

    for k,v in labs_json.items():
        if len(v['regions']) == 0:
            continue
        imgs.append(images_path / v['filename'])
        l = []

        try:
            for rec in v['regions']:
                assert rec['shape_attributes']['name'] == 'rect'
                
                assert rec['shape_attributes']['x'] >0
                assert rec['shape_attributes']['y'] >0
                assert rec['shape_attributes']['width'] >0
                assert rec['shape_attributes']['height'] >0

                # assert rec['region_attributes'].get('act_num')
                l.append([rec['shape_attributes']['x'],
                        rec['shape_attributes']['y'],
                        rec['shape_attributes']['width'],
                        rec['shape_attributes']['height'],
                        int(rec['region_attributes'].get('act_num')) if rec['region_attributes'].get('act_num') else None])
        except Exception as e:
            raise Exception(k)
        labs.append(l)
    return labs,imgs

# %%
labs,imgs = read_labels(Path('src/m1_row_splitter/dataset/ds1_births'))
a,b = read_labels(Path('src/m1_row_splitter/dataset/ds3_al1'))
labs.extend(a)
imgs.extend(b)

imgs,labs = pd.Series(imgs), pd.Series(labs)
# imgs = pd.Series(imgs)
# labs = pd.Series(labs)

# %%
# datasets_df
img_prefixes = imgs.map(lambda x:x.name).str.split('-').str[0]

# %%
gss = GroupShuffleSplit(n_splits=1, test_size=0.3, random_state=67)
split_idx_train, split_idx_val = next(gss.split(imgs, labs, img_prefixes))

# %%
train_imgs, train_labs = pd.Series(imgs)[split_idx_train], pd.Series(labs)[split_idx_train]
val_imgs, val_labs = pd.Series(imgs)[split_idx_val], pd.Series(labs)[split_idx_val]

# %%
print('Subgroups in train:', train_imgs.map(lambda x:x.name).str.split('-').str[0].unique())
print('Subgroups in val:', val_imgs.map(lambda x:x.name).str.split('-').str[0].unique())
# Out:
# Subgroups in train: ['gid429' 'gid515' 'gid634' '226' '236' '808' '995' '1400' '1587' '1652'
#  '1788' '3270' '3302' '3652' '3838' '3849' '4149' '4290' '4384' '4709'
#  '4956' '5046' '5104']
# Subgroups in val: ['gid33' '19' '359' '805' '1146' '1508' '3450' '4080' '4139' '4279']

# %%
IMG_W = 1920
IMG_H = 1440

image_pre_trans = v2.Compose([
    v2.ToImage(), v2.ToDtype(torch.float32, scale=True),
    v2.Resize([IMG_H,IMG_W]),
])

class ScanDataset(Dataset):
    def __init__(self,image_paths,labels): 
        self.labels = []

        self.images = []

        for image_path,labs in tqdm(list(zip(image_paths,labels)), desc='Loading images to ram'):
            img = Image.open(image_path)
            img.load() # Do not lazy-load
            iw,ih = img.size

            scale_x = IMG_W/iw
            scale_y = IMG_H/ih
            labs = [[x,y,x+w,y+h,act] for [x,y,w,h,act] in labs]
            labs = [[x1*scale_x,y1*scale_y,x2*scale_x,y2*scale_y,act] for [x1,y1,x2,y2,act] in labs]

            img_t = image_pre_trans(img)
            self.images.append(img_t)
            self.labels.append(labs)
        

    def __getitem__(self,idx):
        return tv_tensors.Image(self.images[idx]), {
            "boxes": tv_tensors.BoundingBoxes([i[0:4] for i in self.labels[idx]], format="XYXY", canvas_size=(IMG_H,IMG_W)),
            "labels": torch.tensor([1 if i[-1] is None else 2 for i in self.labels[idx]])
        }
    def __len__(self):
        return len(self.images)

# %%
train_ds = ScanDataset(train_imgs,train_labs)
val_ds = ScanDataset(val_imgs,val_labs)
# Out:
# Loading images to ram: 100%|██████████| 207/207 [00:37<00:00,  5.59it/s]
# Loading images to ram: 100%|██████████| 75/75 [00:15<00:00,  4.99it/s]

# %%
import matplotlib.patches as patches

def show_bbox(img, targs,targs2=None,console=True,ret_fig=False):

    fig, ax = plt.subplots()
    ax.imshow(img.permute(1,2,0))
    
    for [x1,y1,x2,y2], lab in zip(targs['boxes'].tolist(),targs['labels'].tolist()):
        if lab==1:
            rect = patches.Rectangle((x1, y1), x2-x1, y2-y1, linewidth=1, edgecolor='r', facecolor='none')
            ax.add_patch(rect)
        else:
            rect = patches.Rectangle((x1, y1), x2-x1, y2-y1, linewidth=1, edgecolor='g', facecolor='none')
            ax.add_patch(rect)
    if targs2 is not None:
        for [x1,y1,x2,y2], lab in zip(targs2['boxes'].tolist(),targs2['labels'].tolist()):
            if lab==1:
                rect = patches.Rectangle((x1, y1), x2-x1, y2-y1, linewidth=1, edgecolor='b', facecolor='none')
                ax.add_patch(rect)
            else:
                rect = patches.Rectangle((x1, y1), x2-x1, y2-y1, linewidth=1, edgecolor='b', facecolor='none')
                ax.add_patch(rect)
    
    if console:
        plt.show()

    if ret_fig:
        return fig
        
    
# tb_writer.add_figure('Pred on val', show_bbox(*train_ds[5], ret_fig=True),global_step=69,close=True)

# %%
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

class BBModel(nn.Module):
    def __init__(self):
        super(BBModel, self).__init__()

        self.model = fasterrcnn_resnet50_fpn(weights="DEFAULT", max_size=max(IMG_H,IMG_W))

        in_features = self.model.roi_heads.box_predictor.cls_score.in_features
        self.model.roi_heads.box_predictor = FastRCNNPredictor(in_features, 3)


    def forward(self, x,targ=None):


        y = self.model(x,targ)

        return y

# %%
import torch

def filter_rcnn_targets(targets, min_size=1.0):
    filtered_targets = []
    
    for target in targets:
        boxes = target.get('boxes')
        
        if boxes is None or len(boxes) == 0:
            filtered_targets.append(target)
            continue
            
        ws = boxes[:, 2] - boxes[:, 0]
        hs = boxes[:, 3] - boxes[:, 1]
        
        valid_mask = (ws > min_size) & (hs > min_size)
        
        if valid_mask.all():
            filtered_targets.append(target)
            continue
            
        filtered_target = {}
        num_boxes = len(boxes)
        
        for key, value in target.items():
            if isinstance(value, torch.Tensor) and len(value) == num_boxes:
                filtered_target[key] = value[valid_mask]
            else:
                filtered_target[key] = value
                
        filtered_targets.append(filtered_target)
        
    return filtered_targets

# %%
aug = v2.Compose([
    # v2.RandomRotation(10),
    v2.RandomPerspective(distortion_scale=0.3),
    v2.RandomAffine(10,(0.05,0.05)),
    v2.ColorJitter(0.2,0.2,0.2),
    v2.ClampBoundingBoxes(),
])

# %%
tb_writer = SummaryWriter('tensorboard_runs/test')

# %%
torch.cuda.empty_cache()

def col_fn(b): 
    return tuple(zip(*b))
train_dl = DataLoader(train_ds, batch_size=4, shuffle=True,collate_fn=col_fn)
val_dl = DataLoader(val_ds, batch_size=1, shuffle=True,collate_fn=col_fn)

mdl = BBModel().to(DEVICE)
opt = torch.optim.AdamW(mdl.parameters(), lr=0.0002)
sch = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(opt,len(train_dl),T_mult=2)
crit = nn.MSELoss()

# g_tloss = []
# g_vloss = []
# g_lr = []

for epoch in range(501):

    mdl.train()
    train_loss_avg = 0
    t = tqdm(train_dl,desc=f'Epoch {epoch}')
    for img,targ in t:
        img = [i.to(DEVICE) for i in img]
        targ = [{k:v.to(DEVICE) for k,v in i.items()} for i in targ]
    
        img,targ = aug(img,targ)
        targ = filter_rcnn_targets(targ)

        ret_dict = mdl(img,targ)

        loss = sum([v for k,v in ret_dict.items()])
        t.set_postfix_str(f'Loss: {loss.item():.03f}, Lr: {sch.get_last_lr()}')
        
        train_loss_avg += loss.item()

        loss.backward()
        opt.step()
        opt.zero_grad()

        sch.step()
    train_loss_avg/= len(train_dl)

    # LOSS ON VAL
    mdl.train()
    val_loss_avg = 0
    with torch.no_grad():
        for img,targ in val_dl:
            img = [i.to(DEVICE) for i in img]
            targ = [{k:v.to(DEVICE) for k,v in i.items()} for i in targ]

            # print(lab[:,:,0:4].size())
            ret_dict = mdl(img,targ)
            # loss = loss_classifier + loss_box_reg + loss_objectness + loss_rpn_box_reg
            val_loss_avg += sum([v for k,v in ret_dict.items()]).item()
    val_loss_avg /= len(val_dl)

    # PRED ON VAL
    mdl.eval()
    with torch.no_grad():
        d = mdl(img)

        img = [i.cpu() for i in img]
        d = [{k:v.cpu() for k,v in i.items()} for i in d]
        
        tb_writer.add_figure('Pred on val', show_bbox(img[0],d[0], targ[0], ret_fig=True,console=False),global_step=epoch,close=True)
    mdl.train()


    tb_writer.add_scalar('Train loss', train_loss_avg, epoch)
    tb_writer.add_scalar('Val loss', val_loss_avg, epoch)
    tb_writer.add_scalar('Learning rate', sch.get_last_lr()[0], epoch)


    # print(epoch+1, 'Train Loss:', train_loss_avg, 'Val Loss:',val_loss_avg)
    # plt.plot(g_tloss)
    # plt.plot(g_vloss)
    # plt.ylim(top=1,bottom=0)
    # plt.show()
    # plt.plot(g_lr)
    # plt.show()
# Out:
# Epoch 0: 100%|██████████| 52/52 [00:59<00:00,  1.15s/it, Loss: 0.795, Lr: [1.824445776682504e-07]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 1: 100%|██████████| 52/52 [00:58<00:00,  1.13s/it, Loss: 0.538, Lr: [0.0001030203027800889]]
# Epoch 2: 100%|██████████| 52/52 [00:58<00:00,  1.13s/it, Loss: 0.507, Lr: [4.562155104665955e-08]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 3: 100%|██████████| 52/52 [00:58<00:00,  1.12s/it, Loss: 0.470, Lr: [0.00017177057293211784]]
# Epoch 4: 100%|██████████| 52/52 [00:58<00:00,  1.12s/it, Loss: 0.455, Lr: [0.00010151032365813862]]
# Epoch 5: 100%|██████████| 52/52 [00:59<00:00,  1.14s/it, Loss: 0.582, Lr: [3.036534726879473e-05]]
# Epoch 6: 100%|██████████| 52/52 [00:59<00:00,  1.15s/it, Loss: 0.299, Lr: [1.1406038250205698e-08]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000002].
# Epoch 7: 100%|██████████| 52/52 [00:59<00:00,  1.15s/it, Loss: 1.014, Lr: [0.00019267431492385521]]
# Epoch 8: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.526, Lr: [0.0001712426570455295]]
# Epoch 9: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.296, Lr: [0.0001389649504483162]]
# Epoch 10: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.257, Lr: [0.00010075518336350218]]
# Epoch 11: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.344, Lr: [6.243044645734917e-05]]
# Epoch 12: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.435, Lr: [2.9825333509213827e-05]]
# Epoch 13: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.223, Lr: [7.903677399364817e-06]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000002].
# Epoch 14: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.323, Lr: [2.851550219240551e-09]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 15: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.363, Lr: [0.00019815149385614444]]
# Epoch 16: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.297, Lr: [0.00019253179373748504]]
# Epoch 17: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.390, Lr: [0.00018335614867792183]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 18: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.474, Lr: [0.00017097717357133284]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 19: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.287, Lr: [0.00015587058548885505]]
# Epoch 20: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.336, Lr: [0.00013861692213862584]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000002].
# Epoch 21: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.433, Lr: [0.00011987923212722869]]
# Epoch 22: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.351, Lr: [0.00010037759437358398]]
# Epoch 23: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.192, Lr: [8.086144587991979e-05]]
# Epoch 24: 100%|██████████| 52/52 [00:55<00:00,  1.06s/it, Loss: 0.167, Lr: [6.208078128806547e-05]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000002].
# Epoch 25: 100%|██████████| 52/52 [00:55<00:00,  1.06s/it, Loss: 0.445, Lr: [4.475733100596796e-05]]
# Epoch 26: 100%|██████████| 52/52 [00:55<00:00,  1.06s/it, Loss: 0.283, Lr: [2.955682551286538e-05]]
# Epoch 27: 100%|██████████| 52/52 [00:56<00:00,  1.09s/it, Loss: 0.210, Lr: [1.7063411710316022e-05]]
# Epoch 28: 100%|██████████| 52/52 [00:59<00:00,  1.14s/it, Loss: 0.250, Lr: [7.757204484364688e-06]]
# Epoch 29: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.283, Lr: [1.9958361597235076e-06]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000002].
# Epoch 30: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.151, Lr: [7.128900958774942e-10]]
# Epoch 31: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.620, Lr: [0.00019953680069606026]]
# Epoch 32: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.397, Lr: [0.00019811518581175014]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000002].
# Epoch 33: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.336, Lr: [0.00019574866805285645]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 34: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.235, Lr: [0.0001924600382790676]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [1.0800148e-05..1.0000002].
# Epoch 35: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.379, Lr: [0.00018828096779285303]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 36: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.218, Lr: [0.00018325170332750732]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 37: 100%|██████████| 52/52 [00:56<00:00,  1.10s/it, Loss: 0.290, Lr: [0.00017742067944910737]]
# Epoch 38: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.223, Lr: [0.00017084405210516406]]
# Epoch 39: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.305, Lr: [0.00016358515781214977]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000002].
# Epoch 40: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.240, Lr: [0.00015571390369022148]]
# Epoch 41: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.281, Lr: [0.00014730609421943855]]
# Epoch 42: 100%|██████████| 52/52 [00:55<00:00,  1.06s/it, Loss: 0.200, Lr: [0.00013844270120118082]]
# Epoch 43: 100%|██████████| 52/52 [00:54<00:00,  1.06s/it, Loss: 0.243, Lr: [0.00012920908395543758]]
# Epoch 44: 100%|██████████| 52/52 [00:55<00:00,  1.07s/it, Loss: 0.429, Lr: [0.00011969416726389402]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 45: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.336, Lr: [0.0001099895849756722]]
# Epoch 46: 100%|██████████| 52/52 [00:56<00:00,  1.09s/it, Loss: 0.451, Lr: [0.00010018879752327202]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000002].
# Epoch 47: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.231, Lr: [9.038619184751549e-05]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 48: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.256, Lr: [8.067617239970951e-05]]
# Epoch 49: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.254, Lr: [7.115225197517304e-05]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [1.0800148e-05..1.0000002].
# Epoch 50: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.329, Lr: [6.190615113389884e-05]]
# Epoch 51: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.192, Lr: [5.302691488142122e-05]]
# Epoch 52: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.201, Lr: [4.460005511673583e-05]]
# Epoch 53: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.177, Lr: [3.6706727105966735e-05]]
# Epoch 54: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.234, Lr: [2.9422947912789678e-05]]
# Epoch 55: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.239, Lr: [2.281886431255361e-05]]
# Epoch 56: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.236, Lr: [1.6958077240488178e-05]]
# Epoch 57: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.336, Lr: [1.1897029279929494e-05]]
# Epoch 58: 100%|██████████| 52/52 [00:56<00:00,  1.08s/it, Loss: 0.142, Lr: [7.68446108938794e-06]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000002].
# Epoch 59: 100%|██████████| 52/52 [00:55<00:00,  1.06s/it, Loss: 0.295, Lr: [4.360942003362456e-06]]
# Epoch 60: 100%|██████████| 52/52 [00:55<00:00,  1.06s/it, Loss: 0.110, Lr: [1.9584793274718516e-06]]
# Epoch 61: 100%|██████████| 52/52 [00:55<00:00,  1.06s/it, Loss: 0.288, Lr: [5.002100906045914e-07]]
# Epoch 62: 100%|██████████| 52/52 [00:55<00:00,  1.06s/it, Loss: 0.244, Lr: [1.7822268278955278e-10]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000002].
# Epoch 63: 100%|██████████| 52/52 [00:55<00:00,  1.06s/it, Loss: 0.303, Lr: [0.00019988413304826254]]
# Epoch 64: 100%|██████████| 52/52 [00:55<00:00,  1.06s/it, Loss: 0.296, Lr: [0.00019952768102687567]]
# Epoch 65: 100%|██████████| 52/52 [00:55<00:00,  1.06s/it, Loss: 0.285, Lr: [0.00019893145810429978]]
# Epoch 66: 100%|██████████| 52/52 [00:55<00:00,  1.06s/it, Loss: 0.276, Lr: [0.00019809690063377834]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 67: 100%|██████████| 52/52 [00:57<00:00,  1.11s/it, Loss: 0.335, Lr: [0.0001970260191373564]]
# Epoch 68: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.283, Lr: [0.00019572139346235703]]
# Epoch 69: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.319, Lr: [0.000194186166566303]]
# Epoch 70: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.290, Lr: [0.00019242403694525687]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 71: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.254, Lr: [0.00019043924972382008]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 72: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.175, Lr: [0.0001882365864282559]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 73: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.184, Lr: [0.00018582135346737388]]
# Epoch 74: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.224, Lr: [0.00018319936934892622]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 75: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.417, Lr: [0.0001803769506623129]]
# Epoch 76: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.240, Lr: [0.00017736089686136466]]
# Epoch 77: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.225, Lr: [0.00017415847388386313]]
# Epoch 78: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.163, Lr: [0.0001707773966472602]]
# Epoch 79: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.302, Lr: [0.00016722581046276627]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 80: 100%|██████████| 52/52 [00:55<00:00,  1.06s/it, Loss: 0.304, Lr: [0.00016351227141258196]]
# Epoch 81: 100%|██████████| 52/52 [00:54<00:00,  1.06s/it, Loss: 0.204, Lr: [0.0001596457257375468]]
# Epoch 82: 100%|██████████| 52/52 [00:55<00:00,  1.07s/it, Loss: 0.208, Lr: [0.00015563548828486133]]
# Epoch 83: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.179, Lr: [0.00015149122006780438]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 84: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.256, Lr: [0.00014722290499150588]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 85: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.226, Lr: [0.0001428408258008449]]
# Epoch 86: 100%|██████████| 52/52 [00:56<00:00,  1.09s/it, Loss: 0.252, Lr: [0.00013835553930841653]]
# Epoch 87: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.148, Lr: [0.0001337778509622457]]
# Epoch 88: 100%|██████████| 52/52 [00:56<00:00,  1.09s/it, Loss: 0.235, Lr: [0.00012911878881451648]]
# Epoch 89: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.220, Lr: [0.00012438957695402845]]
# Epoch 90: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.202, Lr: [0.0001196016084663835]]
# Epoch 91: 100%|██████████| 52/52 [00:56<00:00,  1.10s/it, Loss: 0.151, Lr: [0.00011476641798704491]]
# Epoch 92: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.324, Lr: [0.00010989565391339007]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000002].
# Epoch 93: 100%|██████████| 52/52 [00:56<00:00,  1.09s/it, Loss: 0.176, Lr: [0.00010500105034270098]]
# Epoch 94: 100%|██████████| 52/52 [00:56<00:00,  1.09s/it, Loss: 0.114, Lr: [0.00010009439880369605]]
# Epoch 95: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.205, Lr: [9.518751984970463e-05]]
# Epoch 96: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.156, Lr: [9.029223458191876e-05]]
# Epoch 97: 100%|██████████| 52/52 [00:56<00:00,  1.10s/it, Loss: 0.234, Lr: [8.542033617132489e-05]]
# Epoch 98: 100%|██████████| 52/52 [00:57<00:00,  1.10s/it, Loss: 0.153, Lr: [8.0583561447922e-05]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 99: 100%|██████████| 52/52 [00:56<00:00,  1.08s/it, Loss: 0.182, Lr: [7.579356262567024e-05]]
# Epoch 100: 100%|██████████| 52/52 [00:55<00:00,  1.06s/it, Loss: 0.120, Lr: [7.106187923128674e-05]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000002].
# Epoch 101: 100%|██████████| 52/52 [00:59<00:00,  1.14s/it, Loss: 0.131, Lr: [6.639991030451508e-05]]
# Epoch 102: 100%|██████████| 52/52 [01:03<00:00,  1.23s/it, Loss: 0.207, Lr: [6.181888693684013e-05]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000002].
# Epoch 103: 100%|██████████| 52/52 [01:03<00:00,  1.23s/it, Loss: 0.096, Lr: [5.732984521480484e-05]]
# Epoch 104: 100%|██████████| 52/52 [01:04<00:00,  1.23s/it, Loss: 0.094, Lr: [5.294359963311126e-05]]
# Epoch 105: 100%|██████████| 52/52 [01:03<00:00,  1.23s/it, Loss: 0.174, Lr: [4.8670717041555404e-05]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 106: 100%|██████████| 52/52 [01:04<00:00,  1.24s/it, Loss: 0.209, Lr: [4.4521491188560606e-05]]
# Epoch 107: 100%|██████████| 52/52 [01:03<00:00,  1.23s/it, Loss: 0.104, Lr: [4.0505917922636046e-05]]
# Epoch 108: 100%|██████████| 52/52 [01:02<00:00,  1.21s/it, Loss: 0.233, Lr: [3.6633671111501996e-05]]
# Epoch 109: 100%|██████████| 52/52 [01:02<00:00,  1.20s/it, Loss: 0.196, Lr: [3.291407933689521e-05]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 110: 100%|██████████| 52/52 [01:02<00:00,  1.20s/it, Loss: 0.151, Lr: [2.935610342119852e-05]]
# Epoch 111: 100%|██████████| 52/52 [01:02<00:00,  1.20s/it, Loss: 0.053, Lr: [2.596831484003469e-05]]
# Epoch 112: 100%|██████████| 52/52 [01:02<00:00,  1.20s/it, Loss: 0.177, Lr: [2.2758875072831032e-05]]
# Epoch 113: 100%|██████████| 52/52 [01:02<00:00,  1.20s/it, Loss: 0.157, Lr: [1.9735515941100414e-05]]
# Epoch 114: 100%|██████████| 52/52 [01:02<00:00,  1.20s/it, Loss: 0.095, Lr: [1.6905520981806146e-05]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000002].
# Epoch 115: 100%|██████████| 52/52 [00:59<00:00,  1.14s/it, Loss: 0.084, Lr: [1.4275707900683466e-05]]
# Epoch 116: 100%|██████████| 52/52 [01:03<00:00,  1.22s/it, Loss: 0.139, Lr: [1.1852412147789282e-05]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 117: 100%|██████████| 52/52 [01:13<00:00,  1.42s/it, Loss: 0.363, Lr: [9.641471654847856e-06]]
# Epoch 118: 100%|██████████| 52/52 [01:13<00:00,  1.42s/it, Loss: 0.113, Lr: [7.648212771162267e-06]]
# Epoch 119: 100%|██████████| 52/52 [01:11<00:00,  1.38s/it, Loss: 0.103, Lr: [5.877437431972133e-06]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [1.0800148e-05..1.0000002].
# Epoch 120: 100%|██████████| 52/52 [01:13<00:00,  1.42s/it, Loss: 0.119, Lr: [4.3334115901712106e-06]]
# Epoch 121: 100%|██████████| 52/52 [01:04<00:00,  1.24s/it, Loss: 0.109, Lr: [3.0198549392530306e-06]]
# Epoch 122: 100%|██████████| 52/52 [00:53<00:00,  1.02s/it, Loss: 0.106, Lr: [1.939931952243668e-06]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 123: 100%|██████████| 52/52 [00:53<00:00,  1.02s/it, Loss: 0.078, Lr: [1.0962442582089006e-06]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 124: 100%|██████████| 52/52 [00:53<00:00,  1.02s/it, Loss: 0.110, Lr: [4.908243747019703e-07]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000002].
# Epoch 125: 100%|██████████| 52/52 [00:53<00:00,  1.02s/it, Loss: 0.076, Lr: [1.251308112507732e-07]]
# Epoch 126: 100%|██████████| 52/52 [00:56<00:00,  1.08s/it, Loss: 0.150, Lr: [4.4555680622782034e-11]]
# Epoch 127: 100%|██████████| 52/52 [01:01<00:00,  1.19s/it, Loss: 0.373, Lr: [0.0001999710290654904]]
# Epoch 128: 100%|██████████| 52/52 [01:01<00:00,  1.18s/it, Loss: 0.173, Lr: [0.0001998818504601501]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000002].
# Epoch 129: 100%|██████████| 52/52 [01:01<00:00,  1.18s/it, Loss: 0.216, Lr: [0.00019973250676291553]]
# Epoch 130: 100%|██████████| 52/52 [01:01<00:00,  1.18s/it, Loss: 0.240, Lr: [0.0001995230879328456]]
# Epoch 131: 100%|██████████| 52/52 [01:01<00:00,  1.18s/it, Loss: 0.153, Lr: [0.0001992537201160129]]
# Epoch 132: 100%|██████████| 52/52 [01:01<00:00,  1.18s/it, Loss: 0.526, Lr: [0.00019892456556951793]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000002].
# Epoch 133: 100%|██████████| 52/52 [01:02<00:00,  1.21s/it, Loss: 0.176, Lr: [0.00019853582256375166]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000002].
# Epoch 134: 100%|██████████| 52/52 [01:00<00:00,  1.16s/it, Loss: 0.221, Lr: [0.0001980877252629647]]
# Epoch 135: 100%|██████████| 52/52 [01:08<00:00,  1.32s/it, Loss: 0.157, Lr: [0.00019758054358421563]]
# Epoch 136: 100%|██████████| 52/52 [01:13<00:00,  1.41s/it, Loss: 0.225, Lr: [0.00019701458303478296]]
# Epoch 137: 100%|██████████| 52/52 [01:13<00:00,  1.41s/it, Loss: 0.271, Lr: [0.00019639018452813903]]
# Epoch 138: 100%|██████████| 52/52 [01:13<00:00,  1.42s/it, Loss: 0.178, Lr: [0.00019570772417859655]]
# Epoch 139: 100%|██████████| 52/52 [01:03<00:00,  1.23s/it, Loss: 0.188, Lr: [0.00019496761307475114]]
# Epoch 140: 100%|██████████| 52/52 [00:55<00:00,  1.07s/it, Loss: 0.142, Lr: [0.00019417029703185733]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000001].
# Epoch 141: 100%|██████████| 52/52 [00:53<00:00,  1.03s/it, Loss: 0.189, Lr: [0.0001933162563232857]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.0000002].
# Epoch 142:  33%|███▎      | 17/52 [00:19<00:39,  1.14s/it, Loss: 0.193, Lr: [0.0001930248326634556]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 23
#      19     mdl.train()
#      20     train_loss_avg = 0
#      21     t = tqdm(train_dl,desc=f'Epoch {epoch}')
#      22     for img,targ in t:
# ---> 23         img = [i.to(DEVICE) for i in img]
#      24         targ = [{k:v.to(DEVICE) for k,v in i.items()} for i in targ]
#      25
#      26         img,targ = aug(img,targ)
#
# File f:\Projects\GeneIndex\.venv\Lib\site-packages\torchvision\tv_tensors\_tv_tensor.py:79, in TVTensor.__torch_function__(cls, func, types, args, kwargs)
#      76 # Like in the base Tensor.__torch_function__ implementation, it's easier to always use
#      77 # DisableTorchFunctionSubclass and then manually re-wrap the output if necessary
#      78 with DisableTorchFunctionSubclass():
# ---> 79     output = func(*args, **kwargs or dict())
#      81 must_return_subclass = _must_return_subclass()
#      82 if must_return_subclass or (func in _FORCE_TORCHFUNCTION_SUBCLASS and isinstance(args[0], cls)):
#      83     # If you're wondering why we need the `isinstance(args[0], cls)` check, remove it and see what fails
#      84     # in test_to_tv_tensor_reference().
#    (...)     88     # `args = (a_pure_tensor, an_image)` first. Without this guard, `out` would
#      89     # be wrapped into an `Image`.
#
# KeyboardInterrupt:

# %%
import pickle

# %%
pickle.dump(mdl, open('run4_142e.pkl','wb'))

# %% [markdown]
# # Active learning

# %%
mdl = pickle.load(open('model_203e.pkl','rb'))

# %%
from src.u1_downloader.images_loader import load_all
imgs_df = load_all('datasets/full_scans_random')
# Out:
# Found 3869 images

# %%
def _uncertainty_score(pred):
    scores = pred["scores"]

    if len(scores) == 0:
        return 1.0

    top_scores = scores[:10]

    entropy = -(top_scores * torch.log(top_scores + 1e-8)).mean()

    return entropy.item()

# %%
class ImagePathDS(Dataset):
    def __init__(self, image_paths):
        self.ip = image_paths
    def __getitem__(self,idx):
        return image_pre_trans(Image.open(self.ip[idx]))
    def __len__(self):
        return len(self.ip)

# %%
def get_uncertainty_score_for_all(image_paths):
    ds = ImagePathDS(image_paths)

    uscore = []
    for img in tqdm(ds):
        img = img.unsqueeze(0)
        with torch.no_grad():
            img_cuda = img.to(DEVICE)

            d = mdl(img_cuda)

            # d = [{k:v.cpu() for k,v in i.items()} for i in d]
            # show_bbox(img,d)
        # print(uncertainty_score(d))
        for i in d:
            uscore.append(_uncertainty_score(i))
        # print(uscore[-1])
    return uscore

# %%
u_scores = get_uncertainty_score_for_all(list(imgs_df.image_path))
# Out:
# 100%|██████████| 3869/3869 [18:42<00:00,  3.45it/s]

# %%
# Out:
# Usable 61.44%

# %%
us = pd.Series(u_scores)
us[us==1] = 0

plt.plot(us)
plt.show()

print(f'Usable {(us<0.1).mean()*100:.02f}%')

K=len(us)//75
pooled = us.rolling(K).max().reset_index(drop=True)
us[pooled!=us] = 0
plt.plot(us)
plt.show()
choosen_to_label = imgs_df.image_path[us>0.1]
print('To label:', len(choosen_to_label))
# Out:
# Usable 62.13%
# To label: 99

# %%
import shutil
for path in choosen_to_label:
    # print(r)
    print('Copy', path)
    shutil.copy(path, 'datasets/ds3_al' + '/' + path.split('/')[-1])
# Out:
# Copy datasets/full_scans_random/1146-1886c-007.jpg
# Copy datasets/full_scans_random/1146-1890c-024.jpg
# Copy datasets/full_scans_random/1400-1827-079-080.jpg
# Copy datasets/full_scans_random/1400-1829-046-047.jpg
# Copy datasets/full_scans_random/1400-1841-013-014.jpg
# Copy datasets/full_scans_random/1400-1846-013-014.jpg
# Copy datasets/full_scans_random/1400-1850-097-098.jpg
# Copy datasets/full_scans_random/1400-1852-131.jpg
# Copy datasets/full_scans_random/1400-1869-115.jpg
# Copy datasets/full_scans_random/1400-1874-083.jpg
# Copy datasets/full_scans_random/1400-1884-069.jpg
# Copy datasets/full_scans_random/1400-1885-088.jpg
# Copy datasets/full_scans_random/1400-1886-057.jpg
# Copy datasets/full_scans_random/1400-1906-129-130.jpg
# Copy datasets/full_scans_random/1400-1910-157-158.jpg
# Copy datasets/full_scans_random/1508-1882-140-141.jpg
# Copy datasets/full_scans_random/1508-1895-063-064.jpg
# Copy datasets/full_scans_random/1508-1896-219-220.jpg
# Copy datasets/full_scans_random/1508-1905-141-142.jpg
# Copy datasets/full_scans_random/1587-1907-051-054.jpg
# Copy datasets/full_scans_random/1587-1925-319-322.jpg
# Copy datasets/full_scans_random/1652-1809-k04v.jpg
# Copy datasets/full_scans_random/1652-1818-039-040.jpg
# Copy datasets/full_scans_random/1788-1808a-055-056.jpg
# Copy datasets/full_scans_random/19-1902-118-120.jpg
# Copy datasets/full_scans_random/19-1902-211-213.jpg
# Copy datasets/full_scans_random/19-1902-295-297.jpg
# Copy datasets/full_scans_random/19-1902-655-657.jpg
# Copy datasets/full_scans_random/2186-1906-006.jpg
# Copy datasets/full_scans_random/226-1912-169.jpg
# Copy datasets/full_scans_random/226-1914-065-066.jpg
# Copy datasets/full_scans_random/236-1862-005.jpg
# Copy datasets/full_scans_random/236-1867-k25.jpg
# Copy datasets/full_scans_random/236-1899-k57.jpg
# Copy datasets/full_scans_random/236-1901-B018.jpg
# Copy datasets/full_scans_random/236-1905-B028.jpg
# Copy datasets/full_scans_random/3270-1826-014.jpg
# Copy datasets/full_scans_random/3270-1836-009.jpg
# Copy datasets/full_scans_random/3302-1808-026.jpg
# Copy datasets/full_scans_random/3450-1835-048.jpg
# Copy datasets/full_scans_random/3450-1866-040.jpg
# Copy datasets/full_scans_random/359-1911-107-110.jpg
# Copy datasets/full_scans_random/3652-1797-010.jpg
# Copy datasets/full_scans_random/3652-1797-022.jpg
# Copy datasets/full_scans_random/3652-1812-029.jpg
# Copy datasets/full_scans_random/3652-1812-042.jpg
# Copy datasets/full_scans_random/3652-1820-031.jpg
# Copy datasets/full_scans_random/3652-1820-046.jpg
# Copy datasets/full_scans_random/3652-1840-007.jpg
# Copy datasets/full_scans_random/3652-1851-024.jpg
# Copy datasets/full_scans_random/3652-1860-005.jpg
# Copy datasets/full_scans_random/3838-1902a-036-037.jpg
# Copy datasets/full_scans_random/3838-1902a-109-110.jpg
# Copy datasets/full_scans_random/3838-1902a-157-158.jpg
# Copy datasets/full_scans_random/3849-1896a-053-054.jpg
# Copy datasets/full_scans_random/4080-1878a-158-159.jpg
# Copy datasets/full_scans_random/4080-1879a-124-125.jpg
# Copy datasets/full_scans_random/4080-1880c-032-033.jpg
# Copy datasets/full_scans_random/4080-1881b-026v.jpg
# Copy datasets/full_scans_random/4080-1881c-094-095.jpg
# Copy datasets/full_scans_random/4080-1892c-046-047.jpg
# Copy datasets/full_scans_random/4139-6500-069.jpg
# Copy datasets/full_scans_random/4149-3525-010-011.jpg
# Copy datasets/full_scans_random/4279-6505-176.jpg
# Copy datasets/full_scans_random/4279-7510-039.jpg
# Copy datasets/full_scans_random/4290-5500-002.jpg
# Copy datasets/full_scans_random/4384-5505-013.jpg
# Copy datasets/full_scans_random/4384-5510-021.jpg
# Copy datasets/full_scans_random/4709-3515-001.jpg
# Copy datasets/full_scans_random/4709-3530-007.jpg
# Copy datasets/full_scans_random/4709-7010-070.jpg
# Copy datasets/full_scans_random/4956-3510-020.jpg
# Copy datasets/full_scans_random/4956-3520-060.jpg
# Copy datasets/full_scans_random/5046-5505-024.jpg
# Copy datasets/full_scans_random/5046-5515-057.jpg
# Copy datasets/full_scans_random/5104-4505-010.jpg
# Copy datasets/full_scans_random/805-1808-058-062.jpg
# Copy datasets/full_scans_random/808-1808a-30.jpg
# Copy datasets/full_scans_random/808-1816a-041-043.jpg
# Copy datasets/full_scans_random/808-1821b-14c.jpg
# Copy datasets/full_scans_random/995-1868-001-002.jpg
# Copy datasets/full_scans_random/995-1873-001-002.jpg
# Copy datasets/full_scans_random/995-1884a-057a.jpg
# Copy datasets/full_scans_random/995-1884a-879-882.jpg
# Copy datasets/full_scans_random/995-1888a-1065-1066.jpg
# Copy datasets/full_scans_random/995-1903a-0171-0173.jpg
# Copy datasets/full_scans_random/995-1907a-0087-0090.jpg
# Copy datasets/full_scans_random/995-1907a-0295-0298.jpg
# Copy datasets/full_scans_random/995-1907a-0447-0450.jpg
# Copy datasets/full_scans_random/995-1907b-072-073.jpg
# Copy datasets/full_scans_random/995-1908b-282-283.jpg
# Copy datasets/full_scans_random/995-1914b-066-067.jpg
# Copy datasets/full_scans_random/995-1914b-080-081.jpg
# Copy datasets/full_scans_random/995-1928b-488-489.jpg
# Copy datasets/full_scans_random/995-1934b-050-051.jpg
# Copy datasets/full_scans_random/995-1938b-430-431.jpg
# Copy datasets/full_scans_random/995-7000-013.jpg
# Copy datasets/full_scans_random/995-7000-014.jpg
# Copy datasets/full_scans_random/995-7000-028.jpg
